# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramya72692/Corona/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load COVID-19 dataset
covid_data = pd.read_csv('covid_19_data.csv')

# Display basic information about the dataset
print(covid_data.info())

# Display the first few rows of the dataset
print(covid_data.head())

# Summary statistics
summary_stats = covid_data.describe()

# Visualize the distribution of cases over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='ObservationDate', y='Confirmed', data=covid_data)
plt.title('COVID-19 Confirmed Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Cases')
plt.show()

# Visualize top affected countries
top_countries = covid_data.groupby('Country/Region')['Confirmed'].max().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar', color='skyblue')
plt.title('Top 10 Countries by COVID-19 Confirmed Cases')
plt.xlabel('Country')
plt.ylabel('Number of Cases')
plt.show()

# Exclude non-numeric columns for correlation matrix
numeric_columns = covid_data.select_dtypes(include=[np.number])
correlation_matrix = numeric_columns.corr()

# Visualize the correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60963 entries, 0 to 60962
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SNo              60963 non-null  int64
#  1   ObservationDate  60963 non-null  object
#  2   Province/State   38201 non-null  object
#  3   Country/Region   60963 non-null  object
#  4   Last Update      60962 non-null  object
#  5   Confirmed        60962 non-null  float64
#  6   Deaths           60962 non-null  float64
#  7   Recovered        60962 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 3.7+ MB
# None
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# ...
